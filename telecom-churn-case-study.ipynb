# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/telecom-churn-case-study-hackathon-c34/data_dictionary.csv
# /kaggle/input/telecom-churn-case-study-hackathon-c34/sample.csv
# /kaggle/input/telecom-churn-case-study-hackathon-c34/train.csv
# /kaggle/input/telecom-churn-case-study-hackathon-c34/test (1).csv

# %%
df = pd.read_csv('../input/telecom-churn-case-study-hackathon-c34/train.csv')
df.head()
# Out:
#    id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0   0        109             0.0             0.0             0.0
# 1   1        109             0.0             0.0             0.0
# 2   2        109             0.0             0.0             0.0
# 3   3        109             0.0             0.0             0.0
# 4   4        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8   arpu_6  \
# 0            6/30/2014            7/31/2014            8/31/2014   31.277
# 1            6/30/2014            7/31/2014            8/31/2014    0.000
# 2            6/30/2014            7/31/2014            8/31/2014   60.806
# 3            6/30/2014            7/31/2014            8/31/2014  156.362
# 4            6/30/2014            7/31/2014            8/31/2014  240.708
#
#     arpu_7  ...  sachet_3g_7  sachet_3g_8  fb_user_6  fb_user_7  fb_user_8  \
# 0   87.009  ...            0            0        NaN        NaN        NaN
# 1  122.787  ...            0            0        NaN        1.0        NaN
# 2  103.176  ...            0            0        NaN        NaN        NaN
# 3  205.260  ...            0            0        NaN        NaN        NaN
# 4  128.191  ...            1            0        1.0        1.0        1.0
#
#     aon  aug_vbc_3g  jul_vbc_3g  jun_vbc_3g  churn_probability
# 0  1958         0.0         0.0         0.0                  0
# 1   710         0.0         0.0         0.0                  0
# 2   882         0.0         0.0         0.0                  0
# 3   982         0.0         0.0         0.0                  0
# 4   647         0.0         0.0         0.0                  0
#
# [5 rows x 172 columns]

# %%
# Importing the required Librarires

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df_test = pd.read_csv("../input/telecom-churn-case-study-hackathon-c34/test (1).csv")
df_test.head()
# Out:
#       id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0  69999        109             0.0             0.0             0.0
# 1  70000        109             0.0             0.0             0.0
# 2  70001        109             0.0             0.0             0.0
# 3  70002        109             0.0             0.0             0.0
# 4  70003        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8   arpu_6  \
# 0            6/30/2014            7/31/2014            8/31/2014   91.882
# 1            6/30/2014            7/31/2014            8/31/2014  414.168
# 2            6/30/2014            7/31/2014            8/31/2014  329.844
# 3            6/30/2014            7/31/2014            8/31/2014   43.550
# 4            6/30/2014            7/31/2014            8/31/2014  306.854
#
#     arpu_7  ...  sachet_3g_6  sachet_3g_7  sachet_3g_8  fb_user_6  fb_user_7  \
# 0   65.330  ...            0            0            0        NaN        NaN
# 1  515.568  ...            0            0            0        NaN        NaN
# 2  434.884  ...            0            0            0        NaN        NaN
# 3  171.390  ...            0            0            0        NaN        NaN
# 4  406.289  ...            0            0            0        NaN        NaN
#
#    fb_user_8   aon  aug_vbc_3g  jul_vbc_3g  jun_vbc_3g
# 0        NaN  1692        0.00        0.00        0.00
# 1        NaN  2533        0.00        0.00        0.00
# 2        NaN   277      525.61      758.41      241.84
# 3        NaN  1244        0.00        0.00        0.00
# 4        NaN   462        0.00        0.00        0.00
#
# [5 rows x 171 columns]

# %%
df.shape
# Out:
# (69999, 172)

# %%
df.describe()
# Out:
#                  id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# count  69999.000000    69999.0         69297.0         69297.0
# mean   34999.000000      109.0             0.0             0.0
# std    20207.115084        0.0             0.0             0.0
# min        0.000000      109.0             0.0             0.0
# 25%    17499.500000      109.0             0.0             0.0
# 50%    34999.000000      109.0             0.0             0.0
# 75%    52498.500000      109.0             0.0             0.0
# max    69998.000000      109.0             0.0             0.0
#
#        loc_ic_t2o_mou        arpu_6        arpu_7        arpu_8   onnet_mou_6  \
# count         69297.0  69999.000000  69999.000000  69999.000000  67231.000000
# mean              0.0    283.134365    278.185912    278.858826    133.153275
# std               0.0    334.213918    344.366927    351.924315    299.963093
# min               0.0  -2258.709000  -1289.715000   -945.808000      0.000000
# 25%               0.0     93.581000     86.714000     84.095000      7.410000
# 50%               0.0    197.484000    191.588000    192.234000     34.110000
# 75%               0.0    370.791000    365.369500    369.909000    119.390000
# max               0.0  27731.088000  35145.834000  33543.624000   7376.710000
#
#         onnet_mou_7  ...   sachet_3g_7   sachet_3g_8     fb_user_6  \
# count  67312.000000  ...  69999.000000  69999.000000  17568.000000
# mean     133.894438  ...      0.081444      0.085487      0.916325
# std      311.277193  ...      0.634547      0.680035      0.276907
# min        0.000000  ...      0.000000      0.000000      0.000000
# 25%        6.675000  ...      0.000000      0.000000      1.000000
# 50%       32.280000  ...      0.000000      0.000000      1.000000
# 75%      115.837500  ...      0.000000      0.000000      1.000000
# max     8157.780000  ...     33.000000     41.000000      1.000000
#
#           fb_user_7     fb_user_8           aon    aug_vbc_3g    jul_vbc_3g  \
# count  17865.000000  18417.000000  69999.000000  69999.000000  69999.000000
# mean       0.909544      0.890319   1220.639709     68.108597     65.935830
# std        0.286842      0.312501    952.426321    269.328659    267.899034
# min        0.000000      0.000000    180.000000      0.000000      0.000000
# 25%        1.000000      1.000000    468.000000      0.000000      0.000000
# 50%        1.000000      1.000000    868.000000      0.000000      0.000000
# 75%        1.000000      1.000000   1813.000000      0.000000      0.000000
# max        1.000000      1.000000   4337.000000  12916.220000   9165.600000
#
#         jun_vbc_3g  churn_probability
# count  69999.00000       69999.000000
# mean      60.07674           0.101887
# std      257.22681           0.302502
# min        0.00000           0.000000
# 25%        0.00000           0.000000
# 50%        0.00000           0.000000
# 75%        0.00000           0.000000
# max    11166.21000           1.000000
#
# [8 rows x 163 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69999 entries, 0 to 69998
# Columns: 172 entries, id to churn_probability
# dtypes: float64(135), int64(28), object(9)
# memory usage: 91.9+ MB

# %%
# Finding Unique Values in Columns

uniq1= []
for col in df.columns:
    if df[col].nunique() == 1:
        print(col, df[col].nunique())
        uniq1.append(col)
# Out:
# circle_id 1
# loc_og_t2o_mou 1
# std_og_t2o_mou 1
# loc_ic_t2o_mou 1
# last_date_of_month_6 1
# last_date_of_month_7 1
# last_date_of_month_8 1
# std_og_t2c_mou_6 1
# std_og_t2c_mou_7 1
# std_og_t2c_mou_8 1
# std_ic_t2o_mou_6 1
# std_ic_t2o_mou_7 1
# std_ic_t2o_mou_8 1

# %%
df.drop(columns = uniq1, axis = 1, inplace = True)

# %%
df_test.drop(columns = uniq1, axis = 1, inplace = True)

# %%
null_col = []
for col in df.columns:
    if(df[col].isnull().any()):
        print(col,":", round(df[col].isnull().sum()/ len(df), 3))
        null_col.append(col)
# Out:
# onnet_mou_6 : 0.04
# onnet_mou_7 : 0.038
# onnet_mou_8 : 0.053
# offnet_mou_6 : 0.04
# offnet_mou_7 : 0.038
# offnet_mou_8 : 0.053
# roam_ic_mou_6 : 0.04
# roam_ic_mou_7 : 0.038
# roam_ic_mou_8 : 0.053
# roam_og_mou_6 : 0.04
# roam_og_mou_7 : 0.038
# roam_og_mou_8 : 0.053
# loc_og_t2t_mou_6 : 0.04
# loc_og_t2t_mou_7 : 0.038
# loc_og_t2t_mou_8 : 0.053
# loc_og_t2m_mou_6 : 0.04
# loc_og_t2m_mou_7 : 0.038
# loc_og_t2m_mou_8 : 0.053
# loc_og_t2f_mou_6 : 0.04
# loc_og_t2f_mou_7 : 0.038
# loc_og_t2f_mou_8 : 0.053
# loc_og_t2c_mou_6 : 0.04
# loc_og_t2c_mou_7 : 0.038
# loc_og_t2c_mou_8 : 0.053
# loc_og_mou_6 : 0.04
# loc_og_mou_7 : 0.038
# loc_og_mou_8 : 0.053
# std_og_t2t_mou_6 : 0.04
# std_og_t2t_mou_7 : 0.038
# std_og_t2t_mou_8 : 0.053
# std_og_t2m_mou_6 : 0.04
# std_og_t2m_mou_7 : 0.038
# std_og_t2m_mou_8 : 0.053
# std_og_t2f_mou_6 : 0.04
# std_og_t2f_mou_7 : 0.038
# std_og_t2f_mou_8 : 0.053
# std_og_mou_6 : 0.04
# std_og_mou_7 : 0.038
# std_og_mou_8 : 0.053
# isd_og_mou_6 : 0.04
# isd_og_mou_7 : 0.038
# isd_og_mou_8 : 0.053
# spl_og_mou_6 : 0.04
# spl_og_mou_7 : 0.038
# spl_og_mou_8 : 0.053
# og_others_6 : 0.04
# og_others_7 : 0.038
# og_others_8 : 0.053
# loc_ic_t2t_mou_6 : 0.04
# loc_ic_t2t_mou_7 : 0.038
# loc_ic_t2t_mou_8 : 0.053
# loc_ic_t2m_mou_6 : 0.04
# loc_ic_t2m_mou_7 : 0.038
# loc_ic_t2m_mou_8 : 0.053
# loc_ic_t2f_mou_6 : 0.04
# loc_ic_t2f_mou_7 : 0.038
# loc_ic_t2f_mou_8 : 0.053
# loc_ic_mou_6 : 0.04
# loc_ic_mou_7 : 0.038
# loc_ic_mou_8 : 0.053
# std_ic_t2t_mou_6 : 0.04
# std_ic_t2t_mou_7 : 0.038
# std_ic_t2t_mou_8 : 0.053
# std_ic_t2m_mou_6 : 0.04
# std_ic_t2m_mou_7 : 0.038
# std_ic_t2m_mou_8 : 0.053
# std_ic_t2f_mou_6 : 0.04
# std_ic_t2f_mou_7 : 0.038
# std_ic_t2f_mou_8 : 0.053
# std_ic_mou_6 : 0.04
# std_ic_mou_7 : 0.038
# std_ic_mou_8 : 0.053
# spl_ic_mou_6 : 0.04
# spl_ic_mou_7 : 0.038
# spl_ic_mou_8 : 0.053
# isd_ic_mou_6 : 0.04
# isd_ic_mou_7 : 0.038
# isd_ic_mou_8 : 0.053
# ic_others_6 : 0.04
# ic_others_7 : 0.038
# ic_others_8 : 0.053
# date_of_last_rech_6 : 0.016
# date_of_last_rech_7 : 0.018
# date_of_last_rech_8 : 0.035
# date_of_last_rech_data_6 : 0.749
# date_of_last_rech_data_7 : 0.745
# date_of_last_rech_data_8 : 0.737
# total_rech_data_6 : 0.749
# total_rech_data_7 : 0.745
# total_rech_data_8 : 0.737
# max_rech_data_6 : 0.749
# max_rech_data_7 : 0.745
# max_rech_data_8 : 0.737
# count_rech_2g_6 : 0.749
# count_rech_2g_7 : 0.745
# count_rech_2g_8 : 0.737
# count_rech_3g_6 : 0.749
# count_rech_3g_7 : 0.745
# count_rech_3g_8 : 0.737
# av_rech_amt_data_6 : 0.749
# av_rech_amt_data_7 : 0.745
# av_rech_amt_data_8 : 0.737
# arpu_3g_6 : 0.749
# arpu_3g_7 : 0.745
# arpu_3g_8 : 0.737
# arpu_2g_6 : 0.749
# arpu_2g_7 : 0.745
# arpu_2g_8 : 0.737
# night_pck_user_6 : 0.749
# night_pck_user_7 : 0.745
# night_pck_user_8 : 0.737
# fb_user_6 : 0.749
# fb_user_7 : 0.745
# fb_user_8 : 0.737

# %%
# Counting No of Null values in Column

null_col_test = []
for col in df_test.columns:
    if(df_test[col].isnull().any()):
        print(col,":", round(df_test[col].isnull().sum()/ len(df_test), 3))
        null_col_test.append(col)
# Out:
# onnet_mou_6 : 0.039
# onnet_mou_7 : 0.039
# onnet_mou_8 : 0.056
# offnet_mou_6 : 0.039
# offnet_mou_7 : 0.039
# offnet_mou_8 : 0.056
# roam_ic_mou_6 : 0.039
# roam_ic_mou_7 : 0.039
# roam_ic_mou_8 : 0.056
# roam_og_mou_6 : 0.039
# roam_og_mou_7 : 0.039
# roam_og_mou_8 : 0.056
# loc_og_t2t_mou_6 : 0.039
# loc_og_t2t_mou_7 : 0.039
# loc_og_t2t_mou_8 : 0.056
# loc_og_t2m_mou_6 : 0.039
# loc_og_t2m_mou_7 : 0.039
# loc_og_t2m_mou_8 : 0.056
# loc_og_t2f_mou_6 : 0.039
# loc_og_t2f_mou_7 : 0.039
# loc_og_t2f_mou_8 : 0.056
# loc_og_t2c_mou_6 : 0.039
# loc_og_t2c_mou_7 : 0.039
# loc_og_t2c_mou_8 : 0.056
# loc_og_mou_6 : 0.039
# loc_og_mou_7 : 0.039
# loc_og_mou_8 : 0.056
# std_og_t2t_mou_6 : 0.039
# std_og_t2t_mou_7 : 0.039
# std_og_t2t_mou_8 : 0.056
# std_og_t2m_mou_6 : 0.039
# std_og_t2m_mou_7 : 0.039
# std_og_t2m_mou_8 : 0.056
# std_og_t2f_mou_6 : 0.039
# std_og_t2f_mou_7 : 0.039
# std_og_t2f_mou_8 : 0.056
# std_og_mou_6 : 0.039
# std_og_mou_7 : 0.039
# std_og_mou_8 : 0.056
# isd_og_mou_6 : 0.039
# isd_og_mou_7 : 0.039
# isd_og_mou_8 : 0.056
# spl_og_mou_6 : 0.039
# spl_og_mou_7 : 0.039
# spl_og_mou_8 : 0.056
# og_others_6 : 0.039
# og_others_7 : 0.039
# og_others_8 : 0.056
# loc_ic_t2t_mou_6 : 0.039
# loc_ic_t2t_mou_7 : 0.039
# loc_ic_t2t_mou_8 : 0.056
# loc_ic_t2m_mou_6 : 0.039
# loc_ic_t2m_mou_7 : 0.039
# loc_ic_t2m_mou_8 : 0.056
# loc_ic_t2f_mou_6 : 0.039
# loc_ic_t2f_mou_7 : 0.039
# loc_ic_t2f_mou_8 : 0.056
# loc_ic_mou_6 : 0.039
# loc_ic_mou_7 : 0.039
# loc_ic_mou_8 : 0.056
# std_ic_t2t_mou_6 : 0.039
# std_ic_t2t_mou_7 : 0.039
# std_ic_t2t_mou_8 : 0.056
# std_ic_t2m_mou_6 : 0.039
# std_ic_t2m_mou_7 : 0.039
# std_ic_t2m_mou_8 : 0.056
# std_ic_t2f_mou_6 : 0.039
# std_ic_t2f_mou_7 : 0.039
# std_ic_t2f_mou_8 : 0.056
# std_ic_mou_6 : 0.039
# std_ic_mou_7 : 0.039
# std_ic_mou_8 : 0.056
# spl_ic_mou_6 : 0.039
# spl_ic_mou_7 : 0.039
# spl_ic_mou_8 : 0.056
# isd_ic_mou_6 : 0.039
# isd_ic_mou_7 : 0.039
# isd_ic_mou_8 : 0.056
# ic_others_6 : 0.039
# ic_others_7 : 0.039
# ic_others_8 : 0.056
# date_of_last_rech_6 : 0.017
# date_of_last_rech_7 : 0.018
# date_of_last_rech_8 : 0.039
# date_of_last_rech_data_6 : 0.747
# date_of_last_rech_data_7 : 0.743
# date_of_last_rech_data_8 : 0.736
# total_rech_data_6 : 0.747
# total_rech_data_7 : 0.743
# total_rech_data_8 : 0.736
# max_rech_data_6 : 0.747
# max_rech_data_7 : 0.743
# max_rech_data_8 : 0.736
# count_rech_2g_6 : 0.747
# count_rech_2g_7 : 0.743
# count_rech_2g_8 : 0.736
# count_rech_3g_6 : 0.747
# count_rech_3g_7 : 0.743
# count_rech_3g_8 : 0.736
# av_rech_amt_data_6 : 0.747
# av_rech_amt_data_7 : 0.743
# av_rech_amt_data_8 : 0.736
# arpu_3g_6 : 0.747
# arpu_3g_7 : 0.743
# arpu_3g_8 : 0.736
# arpu_2g_6 : 0.747
# arpu_2g_7 : 0.743
# arpu_2g_8 : 0.736
# night_pck_user_6 : 0.747
# night_pck_user_7 : 0.743
# night_pck_user_8 : 0.736
# fb_user_6 : 0.747
# fb_user_7 : 0.743
# fb_user_8 : 0.736

# %%
# df = df[df.T.isnull().sum()<90]

# %%
filter_df = df.filter(regex = 'arpu')

# %%
for col in filter_df.columns:
    df[col] = df[col].fillna(value = df[col].median())
    df_test[col] = df_test[col].fillna(value = df[col].median())

# %%
# imputing null value of Train with 0

df = df.fillna(value = 0, axis = 1)

# %%
# imputing null value of Test with 0

df_test = df_test.fillna(value = 0, axis = 1)

# %%
df.isnull().sum()
# Out:
# id                   0
# arpu_6               0
# arpu_7               0
# arpu_8               0
# onnet_mou_6          0
#                     ..
# aon                  0
# aug_vbc_3g           0
# jul_vbc_3g           0
# jun_vbc_3g           0
# churn_probability    0
# Length: 159, dtype: int64

# %%
# Dropping ID column from both Train as well as Test Data

df.drop(columns = 'id', axis = 1, inplace = True)
df_test.drop(columns = 'id', axis = 1, inplace = True)

# %%
# Calculating Churn Probability

df['churn_probability'].value_counts()
# Out:
# 0    62867
# 1     7132
# Name: churn_probability, dtype: int64

# %%
# Finding Date Column with Object Type

datecol = []
for col in df.columns:
    if df[col].dtype == 'O':
        print(col)
        datecol.append(col)
# Out:
# date_of_last_rech_6
# date_of_last_rech_7
# date_of_last_rech_8
# date_of_last_rech_data_6
# date_of_last_rech_data_7
# date_of_last_rech_data_8

# %%
# Dropping Date Column from both Train & Test data

df.drop(columns = datecol, axis = 1, inplace = True)
df_test.drop(columns = datecol, axis = 1, inplace = True)

# %%
df.shape
# Out:
# (69999, 152)

# %%
df_test.shape
# Out:
# (30000, 151)

# %%
df1 = df.copy()
for col in df1.columns:
    if col != 'churn_probability':
        percentiles = df1[col].quantile([0.01,0.99]).values
        df1[col][df1[col] <= percentiles[0]] = percentiles[0]
        df_test[col][df_test[col] <= percentiles[0]] = percentiles[0] 
        df1[col][df1[col] >= percentiles[1]] = percentiles[1]
        df_test[col][df_test[col] >= percentiles[1]] = percentiles[1]

# %%
df1.describe()
# Out:
#              arpu_6        arpu_7        arpu_8   onnet_mou_6   onnet_mou_7  \
# count  69999.000000  69999.000000  69999.000000  69999.000000  69999.000000
# mean     276.926861    271.901058    272.341811    120.747130    121.224215
# std      268.478830    269.419465    273.950117    237.768446    243.753462
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       93.581000     86.714000     84.095000      5.430000      4.910000
# 50%      197.484000    191.588000    192.234000     30.830000     29.160000
# 75%      370.791000    365.369500    369.909000    113.100000    108.940000
# max     1400.276640   1414.891380   1445.054800   1429.040400   1461.342200
#
#         onnet_mou_8  offnet_mou_6  offnet_mou_7  offnet_mou_8  roam_ic_mou_6  \
# count  69999.000000  69999.000000  69999.000000  69999.000000   69999.000000
# mean     118.333505    184.197691    182.341078    178.947790       7.202796
# std      239.824631    263.554912    265.383818    261.521972      29.059940
# min        0.000000      0.000000      0.000000      0.000000       0.000000
# 25%        4.110000     28.790000     26.690000     23.780000       0.000000
# 50%       27.840000     89.810000     85.590000     83.010000       0.000000
# 75%      106.280000    223.540000    218.350000    216.410000       0.000000
# max     1448.891000   1520.310000   1517.838600   1492.232400     213.827400
#
#        ...   sachet_3g_7   sachet_3g_8     fb_user_6     fb_user_7  \
# count  ...  69999.000000  69999.000000  69999.000000  69999.000000
# mean   ...      0.054929      0.055872      0.229975      0.232132
# std    ...      0.281017      0.283716      0.420819      0.422196
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      0.000000
# max    ...      2.000000      2.000000      1.000000      1.000000
#
#           fb_user_8           aon    aug_vbc_3g    jul_vbc_3g    jun_vbc_3g  \
# count  69999.000000  69999.000000  69999.000000  69999.000000  69999.000000
# mean       0.234246   1220.188946     60.651021     58.393407     52.577735
# std        0.423530    951.019424    200.381350    199.688297    185.097042
# min        0.000000    188.000000      0.000000      0.000000      0.000000
# 25%        0.000000    468.000000      0.000000      0.000000      0.000000
# 50%        0.000000    868.000000      0.000000      0.000000      0.000000
# 75%        0.000000   1813.000000      0.000000      0.000000      0.000000
# max        1.000000   3651.000000   1226.659800   1254.279000   1188.267800
#
#        churn_probability
# count       69999.000000
# mean            0.101887
# std             0.302502
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000
#
# [8 rows x 152 columns]

# %%
df1.shape
# Out:
# (69999, 152)

# %%
df_test.shape
# Out:
# (30000, 151)

# %%
def plot1(col1, col2, col3, p1, p2, p3):
    plt.figure(figsize=(20, 18))
    if p1==1:
        plt.subplot(3,3,1)
        sns.barplot(x = 'churn_probability', y = col1, data = df1)
        plt.subplot(3,3,2)
        sns.barplot(x = 'churn_probability', y = col2, data = df1)
        plt.subplot(3,3,3)
        sns.barplot(x = 'churn_probability', y = col3, data = df1)
    if p2 ==1:
        plt.subplot(3,3,4)
        sns.boxplot(x = 'churn_probability', y = col1, data = df1)
        plt.subplot(3,3,5)
        sns.boxplot(x = 'churn_probability', y = col2, data = df1)
        plt.subplot(3,3,6)
        sns.boxplot(x = 'churn_probability', y = col3, data = df1)
    if p3 ==1:
        plt.subplot(3,3,7)
        sns.histplot(df1[df1['churn_probability'] == 0][col1], kde = True)
        sns.histplot(df1[df1['churn_probability'] == 1][col1], color = 'red', kde=True)
        plt.legend(['Not churn', 'churn'])
        plt.subplot(3,3,8)
        sns.histplot(df1[df1['churn_probability'] == 0][col2], kde = True)
        sns.histplot(df1[df1['churn_probability'] == 1][col2], color = 'red', kde=True)
        plt.legend(['Not churn', 'churn'])
        plt.subplot(3,3,9)
        sns.histplot(df1[df1['churn_probability'] == 0][col3], kde = True)
        sns.histplot(df1[df1['churn_probability'] == 1][col3], color = 'red', kde=True)
    plt.legend(['Not churn', 'churn'])

# %%
plot1('arpu_6', 'arpu_7', 'arpu_8', 1, 1, 1 )

# %%
plot1('total_ic_mou_6', 'total_ic_mou_7', 'total_ic_mou_8' ,1,1,1)

# %%
plot1('av_rech_amt_data_6', 'av_rech_amt_data_7', 'av_rech_amt_data_8', 1, 0, 0)

# %%
plot1('total_og_mou_6', 'total_og_mou_7', 'total_og_mou_8', 1, 1, 1)

# %%
plot1('onnet_mou_6', 'onnet_mou_7', 'onnet_mou_8', 1, 1,0)

# %%
plot1('offnet_mou_6', 'offnet_mou_7', 'offnet_mou_8', 1, 1,0)

# %%
plot1('total_rech_num_6', 'total_rech_num_7', 'total_rech_num_8', 1, 1, 1)

# %%
plot1('total_rech_amt_6', 'total_rech_amt_7', 'total_rech_amt_8', 1, 1, 1)

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.barplot(x = 'churn_probability', y = 'aon', data = df1)
plt.subplot(2,3,2)
sns.boxplot(x = 'churn_probability', y = 'aon', data = df1)
# Out:
# <AxesSubplot:xlabel='churn_probability', ylabel='aon'>

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.countplot(hue = 'churn_probability', x = 'count_rech_2g_6', data = df1)
plt.subplot(2,3,2)
sns.countplot(hue = 'churn_probability', x = 'count_rech_2g_7', data = df1)
plt.subplot(2,3,3)
sns.countplot(hue = 'churn_probability', x = 'count_rech_2g_8', data = df1)
plt.subplot(2,3,4)
sns.countplot(hue = 'churn_probability', x = 'count_rech_3g_6', data = df1)
plt.subplot(2,3,5)
sns.countplot(hue = 'churn_probability', x = 'count_rech_3g_7', data = df1)
plt.subplot(2,3,6)
sns.countplot(hue = 'churn_probability', x = 'count_rech_3g_8', data = df1)
# Out:
# <AxesSubplot:xlabel='count_rech_3g_8', ylabel='count'>

# %%
plt.figure(figsize=(20, 12))
plt.subplot(2,3,1)
sns.barplot(x = 'churn_probability', y = 'vol_2g_mb_6', data = df1)
plt.subplot(2,3,2)
sns.barplot(x = 'churn_probability', y = 'vol_2g_mb_7', data = df1)
plt.subplot(2,3,3)
sns.barplot(x = 'churn_probability', y = 'vol_2g_mb_8', data = df1)
plt.subplot(2,3,4)
sns.barplot(x = 'churn_probability', y = 'vol_3g_mb_6', data = df1)
plt.subplot(2,3,5)
sns.barplot(x = 'churn_probability', y = 'vol_3g_mb_7', data = df1)
plt.subplot(2,3,6)
sns.barplot(x = 'churn_probability', y = 'vol_3g_mb_8', data = df1)
# Out:
# <AxesSubplot:xlabel='churn_probability', ylabel='vol_3g_mb_8'>

# %%
df1.rename({'last_day_rch_amt_6': 'last_day_rech_amt_6', 'last_day_rch_amt_7': 'last_day_rech_amt_7', 'last_day_rch_amt_8': 'last_day_rech_amt_8'},axis = 1, inplace = True)
df_test.rename({'last_day_rch_amt_6': 'last_day_rech_amt_6', 'last_day_rch_amt_7': 'last_day_rech_amt_7', 'last_day_rch_amt_8': 'last_day_rech_amt_8'},axis = 1, inplace = True)

# %%
rech_df = df1.filter(regex = 'rech')
print(rech_df.columns)
# Out:
# Index(['total_rech_num_6', 'total_rech_num_7', 'total_rech_num_8',
#        'total_rech_amt_6', 'total_rech_amt_7', 'total_rech_amt_8',
#        'max_rech_amt_6', 'max_rech_amt_7', 'max_rech_amt_8',
#        'last_day_rech_amt_6', 'last_day_rech_amt_7', 'last_day_rech_amt_8',
#        'total_rech_data_6', 'total_rech_data_7', 'total_rech_data_8',
#        'max_rech_data_6', 'max_rech_data_7', 'max_rech_data_8',
#        'count_rech_2g_6', 'count_rech_2g_7', 'count_rech_2g_8',
#        'count_rech_3g_6', 'count_rech_3g_7', 'count_rech_3g_8',
#        'av_rech_amt_data_6', 'av_rech_amt_data_7', 'av_rech_amt_data_8'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(22, 15))
sns.heatmap(rech_df.corr(), annot = True)
plt.show()

# %%
total_df = df1.filter(regex = 'total')
total_df.columns
# Out:
# Index(['total_og_mou_6', 'total_og_mou_7', 'total_og_mou_8', 'total_ic_mou_6',
#        'total_ic_mou_7', 'total_ic_mou_8', 'total_rech_num_6',
#        'total_rech_num_7', 'total_rech_num_8', 'total_rech_amt_6',
#        'total_rech_amt_7', 'total_rech_amt_8', 'total_rech_data_6',
#        'total_rech_data_7', 'total_rech_data_8'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(15, 15))
sns.heatmap(total_df.corr(), annot = True)
plt.show()

# %%
amt_df = df1.filter(regex='amt')
print(amt_df.columns)
# Out:
# Index(['total_rech_amt_6', 'total_rech_amt_7', 'total_rech_amt_8',
#        'max_rech_amt_6', 'max_rech_amt_7', 'max_rech_amt_8',
#        'last_day_rech_amt_6', 'last_day_rech_amt_7', 'last_day_rech_amt_8',
#        'av_rech_amt_data_6', 'av_rech_amt_data_7', 'av_rech_amt_data_8'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(10, 10))
sns.heatmap(amt_df.corr(), annot = True)
plt.show()

# %%
ic_mou_df = df1.filter(regex='ic.*mou')
print(ic_mou_df.columns)
# Out:
# Index(['roam_ic_mou_6', 'roam_ic_mou_7', 'roam_ic_mou_8', 'loc_ic_t2t_mou_6',
#        'loc_ic_t2t_mou_7', 'loc_ic_t2t_mou_8', 'loc_ic_t2m_mou_6',
#        'loc_ic_t2m_mou_7', 'loc_ic_t2m_mou_8', 'loc_ic_t2f_mou_6',
#        'loc_ic_t2f_mou_7', 'loc_ic_t2f_mou_8', 'loc_ic_mou_6', 'loc_ic_mou_7',
#        'loc_ic_mou_8', 'std_ic_t2t_mou_6', 'std_ic_t2t_mou_7',
#        'std_ic_t2t_mou_8', 'std_ic_t2m_mou_6', 'std_ic_t2m_mou_7',
#        'std_ic_t2m_mou_8', 'std_ic_t2f_mou_6', 'std_ic_t2f_mou_7',
#        'std_ic_t2f_mou_8', 'std_ic_mou_6', 'std_ic_mou_7', 'std_ic_mou_8',
#        'total_ic_mou_6', 'total_ic_mou_7', 'total_ic_mou_8', 'spl_ic_mou_6',
#        'spl_ic_mou_7', 'spl_ic_mou_8', 'isd_ic_mou_6', 'isd_ic_mou_7',
#        'isd_ic_mou_8'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(30, 30))
sns.heatmap(ic_mou_df.corr(), annot = True)
plt.show()

# %%
og_mou_df = df1.filter(regex='og.*mou')
print(og_mou_df.columns)
# Out:
# Index(['roam_og_mou_6', 'roam_og_mou_7', 'roam_og_mou_8', 'loc_og_t2t_mou_6',
#        'loc_og_t2t_mou_7', 'loc_og_t2t_mou_8', 'loc_og_t2m_mou_6',
#        'loc_og_t2m_mou_7', 'loc_og_t2m_mou_8', 'loc_og_t2f_mou_6',
#        'loc_og_t2f_mou_7', 'loc_og_t2f_mou_8', 'loc_og_t2c_mou_6',
#        'loc_og_t2c_mou_7', 'loc_og_t2c_mou_8', 'loc_og_mou_6', 'loc_og_mou_7',
#        'loc_og_mou_8', 'std_og_t2t_mou_6', 'std_og_t2t_mou_7',
#        'std_og_t2t_mou_8', 'std_og_t2m_mou_6', 'std_og_t2m_mou_7',
#        'std_og_t2m_mou_8', 'std_og_t2f_mou_6', 'std_og_t2f_mou_7',
#        'std_og_t2f_mou_8', 'std_og_mou_6', 'std_og_mou_7', 'std_og_mou_8',
#        'isd_og_mou_6', 'isd_og_mou_7', 'isd_og_mou_8', 'spl_og_mou_6',
#        'spl_og_mou_7', 'spl_og_mou_8', 'total_og_mou_6', 'total_og_mou_7',
#        'total_og_mou_8'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(30, 30))
sns.heatmap(og_mou_df.corr(), annot = True)
plt.show()

# %%
g3_df = df1.filter(regex='3g')
print(g3_df.columns)
# Out:
# Index(['count_rech_3g_6', 'count_rech_3g_7', 'count_rech_3g_8', 'vol_3g_mb_6',
#        'vol_3g_mb_7', 'vol_3g_mb_8', 'arpu_3g_6', 'arpu_3g_7', 'arpu_3g_8',
#        'monthly_3g_6', 'monthly_3g_7', 'monthly_3g_8', 'sachet_3g_6',
#        'sachet_3g_7', 'sachet_3g_8', 'aug_vbc_3g', 'jul_vbc_3g', 'jun_vbc_3g'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(15, 10))
sns.heatmap(g3_df.corr(), annot = True)
plt.show()

# %%
g2_df = df1.filter(regex='2g')
print(g2_df.columns)
# Out:
# Index(['count_rech_2g_6', 'count_rech_2g_7', 'count_rech_2g_8', 'vol_2g_mb_6',
#        'vol_2g_mb_7', 'vol_2g_mb_8', 'arpu_2g_6', 'arpu_2g_7', 'arpu_2g_8',
#        'monthly_2g_6', 'monthly_2g_7', 'monthly_2g_8', 'sachet_2g_6',
#        'sachet_2g_7', 'sachet_2g_8'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(15, 10))
sns.heatmap(g2_df.corr(), annot = True)
plt.show()

# %%
# To remove High multicollinearity features:
# count_rech...
# local_ic_t2m_mou
# local_ic_mou,
# std_ic_t2m_mou
# local_og_t2m_mou
# local_og_mou,
# std_og_t2m_mou
# total_og_mou
# last_day_rech_amt

# %%
to_drop = []
tempdf = df1.filter(regex='count_rech')
to_drop.extend(tempdf.columns)

# %%
tempdf = df1.filter(regex='t2m')
to_drop.extend(tempdf.columns)

# %%
tempdf = df1.filter(regex='loc_ic_mou')
to_drop.extend(tempdf.columns)

# %%
tempdf = df1.filter(regex='loc_og_mou')
to_drop.extend(tempdf.columns)

# %%
to_drop.extend(['last_day_rech_amt_6', 'last_day_rech_amt_7', 'last_day_rech_amt_8'])

# %%
to_drop
# Out:
# ['count_rech_2g_6',
#  'count_rech_2g_7',
#  'count_rech_2g_8',
#  'count_rech_3g_6',
#  'count_rech_3g_7',
#  'count_rech_3g_8',
#  'loc_og_t2m_mou_6',
#  'loc_og_t2m_mou_7',
#  'loc_og_t2m_mou_8',
#  'std_og_t2m_mou_6',
#  'std_og_t2m_mou_7',
#  'std_og_t2m_mou_8',
#  'loc_ic_t2m_mou_6',
#  'loc_ic_t2m_mou_7',
#  'loc_ic_t2m_mou_8',
#  'std_ic_t2m_mou_6',
#  'std_ic_t2m_mou_7',
#  'std_ic_t2m_mou_8',
#  'loc_ic_mou_6',
#  'loc_ic_mou_7',
#  'loc_ic_mou_8',
#  'loc_og_mou_6',
#  'loc_og_mou_7',
#  'loc_og_mou_8',
#  'last_day_rech_amt_6',
#  'last_day_rech_amt_7',
#  'last_day_rech_amt_8']

# %%
df1.drop(columns = to_drop, axis =1, inplace = True)
df_test.drop(columns = to_drop, axis =1, inplace = True)

# %%
df1.shape
# Out:
# (69999, 125)

# %%
df_test.shape
# Out:
# (30000, 124)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X = df1.drop('churn_probability', axis = 1)
y = df1['churn_probability']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

# %%
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
from sklearn.decomposition import PCA

pca = PCA(random_state=42)
pca.fit(X_train_sc)
# Out:
# PCA(random_state=42)

# %%
pca.components_
# Out:
# array([[ 1.50148948e-01,  1.62454796e-01,  1.56014978e-01, ...,
#          1.36108246e-01,  1.37705121e-01,  1.31141206e-01],
#        [ 1.30776672e-01,  1.46026593e-01,  1.32472904e-01, ...,
#         -8.47862552e-02, -8.63748828e-02, -8.41287852e-02],
#        [ 1.44079465e-03, -1.43024916e-02, -8.41162667e-03, ...,
#          8.78850180e-03,  8.74498963e-03,  1.09783882e-02],
#        ...,
#        [-0.00000000e+00,  6.86658064e-17, -8.12417462e-17, ...,
#         -6.90375276e-17,  4.41660019e-17,  3.66956483e-17],
#        [-0.00000000e+00,  1.46804977e-17,  3.53455948e-17, ...,
#         -7.58165049e-17,  1.05198974e-16, -4.86671816e-17],
#        [-0.00000000e+00,  3.67643989e-17,  3.12457528e-17, ...,
#          2.23812168e-17, -2.83050882e-17,  3.14267574e-18]])

# %%
pca.explained_variance_ratio_
# Out:
# array([1.50526638e-01, 1.10227360e-01, 6.04807524e-02, 4.69125606e-02,
#        3.49289426e-02, 2.99135781e-02, 2.79695552e-02, 2.73396165e-02,
#        2.59729363e-02, 2.45341045e-02, 2.23952666e-02, 2.00764748e-02,
#        1.84887714e-02, 1.70887037e-02, 1.63992710e-02, 1.58670874e-02,
#        1.43486505e-02, 1.39137617e-02, 1.27408452e-02, 1.24406840e-02,
#        1.13145338e-02, 1.06977311e-02, 1.05848746e-02, 9.61984240e-03,
#        9.46048690e-03, 9.37021334e-03, 9.00113723e-03, 7.91250558e-03,
#        7.68368720e-03, 7.52001697e-03, 7.19119150e-03, 6.95767793e-03,
#        6.84453045e-03, 6.78881058e-03, 6.60153074e-03, 6.14463265e-03,
#        6.06332475e-03, 5.99617738e-03, 5.59635963e-03, 5.47940448e-03,
#        5.41235385e-03, 5.15837683e-03, 4.80518255e-03, 4.78365268e-03,
#        4.54005863e-03, 4.29347831e-03, 4.20330806e-03, 3.95289066e-03,
#        3.80171620e-03, 3.72323866e-03, 3.71227193e-03, 3.66088357e-03,
#        3.55403558e-03, 3.43980525e-03, 3.36896516e-03, 3.25767964e-03,
#        3.13985636e-03, 2.96946652e-03, 2.89233160e-03, 2.77569754e-03,
#        2.74422492e-03, 2.67194365e-03, 2.64363142e-03, 2.50606446e-03,
#        2.42072371e-03, 2.41048788e-03, 2.37896592e-03, 2.26393646e-03,
#        2.23404194e-03, 2.13290193e-03, 1.94619378e-03, 1.88453760e-03,
#        1.87717166e-03, 1.83444915e-03, 1.77362159e-03, 1.69376968e-03,
#        1.65763988e-03, 1.54367349e-03, 1.41068528e-03, 1.38352941e-03,
#        1.34056831e-03, 1.32156336e-03, 1.29651607e-03, 1.16745023e-03,
#        1.15448120e-03, 1.11754776e-03, 1.06285035e-03, 1.02845486e-03,
#        9.84982595e-04, 8.63410150e-04, 8.03082674e-04, 7.79785598e-04,
#        6.63516739e-04, 6.38424723e-04, 6.23236660e-04, 5.77920271e-04,
#        5.61909975e-04, 5.50654382e-04, 5.35333699e-04, 4.64945815e-04,
#        4.52186366e-04, 4.07086786e-04, 3.81275996e-04, 3.61365367e-04,
#        3.18641962e-04, 3.02335724e-04, 2.76283597e-04, 2.59086170e-04,
#        2.28752426e-04, 2.18448885e-04, 2.11187593e-04, 1.72056703e-04,
#        1.37533637e-04, 1.35550342e-04, 9.45291615e-05, 8.41971049e-05,
#        6.68647983e-05, 6.37478037e-05, 4.05606880e-05, 1.33532727e-33,
#        8.39644567e-34, 8.39644567e-34, 8.39644567e-34, 8.39644567e-34])

# %%
var_cum = np.cumsum(pca.explained_variance_ratio_)

# %%
fig = plt.figure(figsize=[8,5])
plt.vlines(x=59, ymax=1, ymin=0, colors="r", linestyles="--")
plt.hlines(y=0.95, xmax=198, xmin=0, colors="g", linestyles="--")
plt.plot(var_cum)
plt.ylabel("Cumulative variance explained")
plt.show()

# %%
# Calculating the Principle components for variance cover of 95%
pca_ag = PCA(0.95)

# %%
#Applying PCA components to train data set

df_train_pca = pca_ag.fit_transform(X_train_sc)

df_train_pca.shape
# Out:
# (55999, 66)

# %%
# Applying the PCA components to Test Data Set

df_test_pca = pca_ag.transform(X_test_sc)

df_test_pca.shape
# Out:
# (14000, 66)

# %%
corrmat = np.corrcoef(df_train_pca.transpose())

corrmat.shape
# Out:
# (66, 66)

# %%
plt.figure(figsize = (30, 30))
sns.heatmap(corrmat)
plt.show()

# %%
pca_ag_2 = PCA(n_components = 2)

# %%
df_pca = pca_ag_2.fit_transform(X_train_sc)

df_pca.shape
# Out:
# (55999, 2)

# %%
tele_df = pd.DataFrame(data = df_pca ,columns = ['PC_1' , 'PC_2'])

# %%
tele_df.tail()
# Out:
#            PC_1      PC_2
# 55994 -3.302858 -1.008093
# 55995  2.593959  4.808090
# 55996 -2.812486 -0.846520
# 55997  6.793553 -5.924418
# 55998  7.558576  3.269252

# %%
print('Explained variation per principal component: {}'.format(pca_ag_2.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.15052664 0.11022736]

# %%
finalDf=pd.concat([tele_df ,df1['churn_probability'].reset_index(drop = True)],axis=1)
finalDf.head()
# Out:
#        PC_1      PC_2  churn_probability
# 0 -4.043341 -1.795105                  0
# 1 -0.857220  1.907372                  0
# 2  6.426326 -3.922082                  0
# 3 -2.774608 -0.556818                  0
# 4 -1.461274  1.330065                  0

# %%
fig=plt.figure(figsize=(8,8))  
ax=fig.add_subplot(1,1,1)  
ax.set_xlabel('Principal Component 1',fontsize = 15)  
ax.set_ylabel('Principal Component 2',fontsize = 15)  
ax.set_title('2 PCA Components',fontsize=20)
sns.scatterplot( finalDf['PC_2'],finalDf['PC_1'], hue = finalDf['churn_probability'])
# Out:
# <AxesSubplot:title={'center':'2 PCA Components'}, xlabel='Principal Component 1', ylabel='Principal Component 2'>

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, RepeatedStratifiedKFold, StratifiedKFold, RandomizedSearchCV
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.feature_selection import RFE

# %%
fold = StratifiedKFold(n_splits = 3)

# %%
grid = [
    {    "penalty":['l1','l2'],
        "class_weight":[{0:1,1:1}, {0:1,1:2}, {0:1,1:3}]
    }    
]

gscv = GridSearchCV(LogisticRegression(solver='lbfgs'), grid, cv = fold , scoring = 'accuracy', verbose = 1, n_jobs = -1)

# %%
gfit = gscv.fit(df_train_pca, y_train)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits

# %%
print("score : {}".format(gfit.best_score_))
logistic_params = gfit.best_params_
print(logistic_params)
# Out:
# score : 0.914712782763157
# {'class_weight': {0: 1, 1: 2}, 'penalty': 'l2'}

# %%
lr_best = gfit.best_estimator_

# %%
print(lr_best.coef_.shape)
lr_best.coef_
# Out:
# (1, 66)
# array([[-2.90853538e-01, -1.64966924e-01, -3.44334708e-01,
#         -4.31804309e-01,  1.76169111e-01,  1.58614389e-01,
#          2.28202781e-01,  3.68150658e-01,  5.38282639e-01,
#          3.24468032e-02, -6.27903187e-02,  6.01630244e-02,
#          2.01335973e-02,  6.62451707e-02,  2.14363479e-02,
#          3.77785711e-01,  4.24550523e-03,  1.10046992e-01,
#          2.58714033e-01, -1.97057009e-01,  6.26793220e-02,
#          1.01879107e-01, -1.49133227e-01,  4.03590182e-04,
#          2.98206931e-01,  3.40660417e-01, -1.25639912e-02,
#          2.75478170e-01,  9.22441095e-02,  4.09063145e-02,
#         -2.87456075e-01, -6.38755508e-01,  1.24733202e-01,
#         -4.15119252e-01,  1.36145869e-02,  2.63488572e-01,
#         -6.97628026e-02,  1.91703501e-02, -4.09661147e-02,
#          3.19915171e-01, -4.40985545e-02, -1.03946690e-01,
#         -1.62787557e-02, -7.92476409e-02, -1.88827294e-01,
#          1.26536888e-01, -1.63341879e-01,  3.34371611e-01,
#          1.08691360e-01,  3.59456783e-01, -3.51219644e-02,
#          1.02336760e-01, -2.55704969e-02,  1.49925280e-01,
#          4.02949076e-01,  9.11286884e-03, -3.25462448e-02,
#          5.55871655e-02,  3.71703109e-02,  1.96061168e-01,
#          2.41060385e-01, -1.93695074e-02,  4.37202678e-02,
#          2.00065540e-02, -8.76196408e-02, -2.72487661e-01]])

# %%
y_pred = lr_best.predict(df_test_pca)

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[12066   542]
#  [  615   777]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95     12608
#            1       0.59      0.56      0.57      1392
#
#     accuracy                           0.92     14000
#    macro avg       0.77      0.76      0.76     14000
# weighted avg       0.92      0.92      0.92     14000

# %%
grid2 = [
    {   'n_estimators' : [250],
        'max_depth' : [ 7], 
        'max_features' : [ 15],
        'min_samples_split':[3, 4],
        'min_samples_leaf':[1,2],
        "class_weight":['balanced', {0:1,1:10}]
    }    
]

gscv2 = HalvingGridSearchCV(RandomForestClassifier(random_state = 100), grid2, cv = fold , scoring = 'accuracy', verbose = 1, n_jobs = -1)

# %%
gfit2 = gscv2.fit(df_train_pca, y_train)
# Out:
# n_iterations: 2
# n_required_iterations: 2
# n_possible_iterations: 2
# min_resources_: 18666
# max_resources_: 55999
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 8
# n_resources: 18666
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# ----------
# iter: 1
# n_candidates: 3
# n_resources: 55998
# Fitting 3 folds for each of 3 candidates, totalling 9 fits

# %%
print("score : {}".format(gfit2.best_score_))
gfit2.best_params_
# Out:
# score : 0.8600256780821273
# {'class_weight': 'balanced',
#  'max_depth': 7,
#  'max_features': 15,
#  'min_samples_leaf': 1,
#  'min_samples_split': 3,
#  'n_estimators': 250}

# %%
rf_best = gfit2.best_estimator_

# %%
rf_best.feature_importances_
# Out:
# array([0.085638  , 0.01514153, 0.08424579, 0.10474919, 0.03823899,
#        0.01357301, 0.03063664, 0.18269462, 0.11447849, 0.0081074 ,
#        0.0037184 , 0.00839719, 0.00802757, 0.01583012, 0.00512163,
#        0.05409964, 0.00537756, 0.00633804, 0.00667723, 0.0033419 ,
#        0.00307062, 0.00210892, 0.01197833, 0.00298074, 0.01242149,
#        0.00973648, 0.00908595, 0.00619228, 0.01366525, 0.00449459,
#        0.00301031, 0.02030137, 0.00510943, 0.00472187, 0.00662932,
#        0.00872391, 0.00231153, 0.00194012, 0.00286636, 0.00532037,
#        0.00108418, 0.00223926, 0.00282211, 0.00554964, 0.00152776,
#        0.00234106, 0.00248044, 0.00878095, 0.00212772, 0.00273562,
#        0.00167775, 0.00178963, 0.00238994, 0.00278183, 0.00545401,
#        0.00113379, 0.00160421, 0.00124268, 0.00310286, 0.00425469,
#        0.00239172, 0.00234326, 0.00266997, 0.00137206, 0.00125205,
#        0.00174862])

# %%
y_pred2 = rf_best.predict(df_test_pca)

# %%
print(confusion_matrix(y_test, y_pred2))
# Out:
# [[10952  1656]
#  [  328  1064]]

# %%
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92     12608
#            1       0.39      0.76      0.52      1392
#
#     accuracy                           0.86     14000
#    macro avg       0.68      0.82      0.72     14000
# weighted avg       0.91      0.86      0.88     14000

# %%
grid3 = [
    { 
        'n_estimators': [1200],
        'learning_rate': [0.01],
        'max_depth': [4,5],
        'min_child_weight': [2],
        "class_weight":[{0:1,1:10}, 'balanced' ]
    }    
]

gscv3 = RandomizedSearchCV(XGBClassifier(random_state = 100, tree_method='gpu_hist', predictor='gpu_predictor'), grid3, cv = fold , scoring = 'accuracy', n_jobs = -1, n_iter=20)

# %%
conda install -c conda-forge py-xgboost-gpu
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - py-xgboost-gpu
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _py-xgboost-mutex-2.0      |            gpu_0          12 KB  conda-forge
#     certifi-2021.10.8          |   py37h89c1867_2         145 KB  conda-forge
#     conda-4.12.0               |   py37h89c1867_0         1.0 MB  conda-forge
#     libxgboost-1.5.1           |cuda110h6a8d290_2       247.2 MB  conda-forge
#     openssl-1.1.1n             |       h166bdaf_0         2.1 MB  conda-forge
#     py-xgboost-1.5.1           |cuda110py37h68f1ac2_2         151 KB  conda-forge
#     py-xgboost-gpu-1.5.1       |   py37h68f1ac2_2          12 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       250.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _py-xgboost-mutex  conda-forge/linux-64::_py-xgboost-mutex-2.0-gpu_0
#   libxgboost         conda-forge/linux-64::libxgboost-1.5.1-cuda110h6a8d290_2
#   py-xgboost         conda-forge/linux-64::py-xgboost-1.5.1-cuda110py37h68f1ac2_2
#   py-xgboost-gpu     conda-forge/linux-64::py-xgboost-gpu-1.5.1-py37h68f1ac2_2
#
# The following packages will be UPDATED:
#
#   certifi                          2021.10.8-py37h89c1867_1 --> 2021.10.8-py37h89c1867_2
#   conda                               4.11.0-py37h89c1867_2 --> 4.12.0-py37h89c1867_0
#   openssl                                 1.1.1l-h7f98852_0 --> 1.1.1n-h166bdaf_0
#
#
#
# Downloading and Extracting Packages
# conda-4.12.0         | 1.0 MB    | ##################################### | 100%
# _py-xgboost-mutex-2. | 12 KB     | ##################################### | 100%
# certifi-2021.10.8    | 145 KB    | ##################################### | 100%
# py-xgboost-gpu-1.5.1 | 12 KB     | ##################################### | 100%
# openssl-1.1.1n       | 2.1 MB    | ##################################### | 100%
# libxgboost-1.5.1     | 247.2 MB  | ##################################### | 100%
# py-xgboost-1.5.1     | 151 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
gfit3 = gscv3.fit(df_train_pca, y_train)
# Out:
# [17:09:31] WARNING: ../src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:31] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
print("score : {}".format(gfit3.best_score_))
xgbparams = gfit3.best_params_
print(xgbparams)
# Out:
# score : 0.9201414179718398
# {'n_estimators': 1200, 'min_child_weight': 2, 'max_depth': 5, 'learning_rate': 0.01, 'class_weight': {0: 1, 1: 10}}

# %%
xgb_best = gfit3.best_estimator_

# %%
xgb_best.feature_importances_
# Out:
# array([0.05633458, 0.02782464, 0.06089136, 0.04117493, 0.02518128,
#        0.01224814, 0.02232603, 0.07085446, 0.04621948, 0.00962055,
#        0.00839277, 0.00998027, 0.00695697, 0.01026775, 0.01436627,
#        0.02732953, 0.01083377, 0.00815378, 0.01513877, 0.00867894,
#        0.00940887, 0.0066405 , 0.01641386, 0.00939059, 0.01982852,
#        0.0162255 , 0.01494912, 0.0121078 , 0.01754093, 0.01214678,
#        0.01124931, 0.02034996, 0.0116486 , 0.01311135, 0.0115976 ,
#        0.01870507, 0.00761428, 0.00956109, 0.00909721, 0.0135502 ,
#        0.0073802 , 0.00935467, 0.00937217, 0.01267344, 0.01028477,
#        0.00812298, 0.00788163, 0.01622434, 0.00921712, 0.01101767,
#        0.00751167, 0.00851762, 0.00893183, 0.00869465, 0.00998135,
#        0.0071552 , 0.00813565, 0.0075033 , 0.01011448, 0.01111521,
#        0.01092588, 0.0077518 , 0.00886171, 0.00915799, 0.01001064,
#        0.01019067], dtype=float32)

# %%
y_pred3 = xgb_best.predict(df_test_pca)

# %%
print(confusion_matrix(y_test, y_pred3))
# Out:
# [[12338   270]
#  [  788   604]]

# %%
print(classification_report(y_test, y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     12608
#            1       0.69      0.43      0.53      1392
#
#     accuracy                           0.92     14000
#    macro avg       0.82      0.71      0.75     14000
# weighted avg       0.92      0.92      0.92     14000

# %%
# Selecting top 60 features using RFE
rfe = RFE(estimator = LogisticRegression(), n_features_to_select = 60)

# %%
rfe_fit = rfe.fit(X_train_sc, y_train)
# Out:
# [17:08:37] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:39] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:08:47] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:47] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:08:54] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:54] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:09:05] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:05] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:09:11] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:11] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:09:18] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:18] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [17:08:37] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:39] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:08:47] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:47] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:08:57] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:08:57] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:09:08] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:08] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:09:14] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:14] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [17:09:25] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:576:
# Parameters: { "class_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [17:09:25] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1645117937192/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)

# %%
list(zip(X_train.columns, rfe.support_, rfe.ranking_))
# Out:
# [('arpu_6', True, 1),
#  ('arpu_7', True, 1),
#  ('arpu_8', True, 1),
#  ('onnet_mou_6', False, 58),
#  ('onnet_mou_7', True, 1),
#  ('onnet_mou_8', False, 36),
#  ('offnet_mou_6', False, 54),
#  ('offnet_mou_7', False, 43),
#  ('offnet_mou_8', True, 1),
#  ('roam_ic_mou_6', False, 38),
#  ('roam_ic_mou_7', True, 1),
#  ('roam_ic_mou_8', False, 57),
#  ('roam_og_mou_6', False, 9),
#  ('roam_og_mou_7', False, 42),
#  ('roam_og_mou_8', True, 1),
#  ('loc_og_t2t_mou_6', False, 45),
#  ('loc_og_t2t_mou_7', False, 20),
#  ('loc_og_t2t_mou_8', True, 1),
#  ('loc_og_t2f_mou_6', False, 15),
#  ('loc_og_t2f_mou_7', False, 50),
#  ('loc_og_t2f_mou_8', False, 48),
#  ('loc_og_t2c_mou_6', False, 37),
#  ('loc_og_t2c_mou_7', False, 55),
#  ('loc_og_t2c_mou_8', True, 1),
#  ('std_og_t2t_mou_6', False, 14),
#  ('std_og_t2t_mou_7', True, 1),
#  ('std_og_t2t_mou_8', True, 1),
#  ('std_og_t2f_mou_6', False, 4),
#  ('std_og_t2f_mou_7', False, 51),
#  ('std_og_t2f_mou_8', True, 1),
#  ('std_og_mou_6', True, 1),
#  ('std_og_mou_7', False, 19),
#  ('std_og_mou_8', True, 1),
#  ('isd_og_mou_6', False, 52),
#  ('isd_og_mou_7', True, 1),
#  ('isd_og_mou_8', True, 1),
#  ('spl_og_mou_6', False, 27),
#  ('spl_og_mou_7', False, 26),
#  ('spl_og_mou_8', True, 1),
#  ('og_others_6', False, 35),
#  ('og_others_7', False, 61),
#  ('og_others_8', False, 63),
#  ('total_og_mou_6', True, 1),
#  ('total_og_mou_7', True, 1),
#  ('total_og_mou_8', True, 1),
#  ('loc_ic_t2t_mou_6', False, 44),
#  ('loc_ic_t2t_mou_7', False, 33),
#  ('loc_ic_t2t_mou_8', True, 1),
#  ('loc_ic_t2f_mou_6', False, 6),
#  ('loc_ic_t2f_mou_7', True, 1),
#  ('loc_ic_t2f_mou_8', True, 1),
#  ('std_ic_t2t_mou_6', False, 34),
#  ('std_ic_t2t_mou_7', True, 1),
#  ('std_ic_t2t_mou_8', False, 23),
#  ('std_ic_t2f_mou_6', False, 16),
#  ('std_ic_t2f_mou_7', False, 22),
#  ('std_ic_t2f_mou_8', True, 1),
#  ('std_ic_mou_6', False, 7),
#  ('std_ic_mou_7', True, 1),
#  ('std_ic_mou_8', True, 1),
#  ('total_ic_mou_6', True, 1),
#  ('total_ic_mou_7', True, 1),
#  ('total_ic_mou_8', True, 1),
#  ('spl_ic_mou_6', True, 1),
#  ('spl_ic_mou_7', True, 1),
#  ('spl_ic_mou_8', True, 1),
#  ('isd_ic_mou_6', False, 5),
#  ('isd_ic_mou_7', False, 56),
#  ('isd_ic_mou_8', True, 1),
#  ('ic_others_6', False, 32),
#  ('ic_others_7', False, 41),
#  ('ic_others_8', False, 8),
#  ('total_rech_num_6', False, 18),
#  ('total_rech_num_7', False, 17),
#  ('total_rech_num_8', True, 1),
#  ('total_rech_amt_6', True, 1),
#  ('total_rech_amt_7', True, 1),
#  ('total_rech_amt_8', True, 1),
#  ('max_rech_amt_6', False, 60),
#  ('max_rech_amt_7', True, 1),
#  ('max_rech_amt_8', True, 1),
#  ('total_rech_data_6', True, 1),
#  ('total_rech_data_7', True, 1),
#  ('total_rech_data_8', True, 1),
#  ('max_rech_data_6', True, 1),
#  ('max_rech_data_7', False, 11),
#  ('max_rech_data_8', True, 1),
#  ('av_rech_amt_data_6', True, 1),
#  ('av_rech_amt_data_7', False, 10),
#  ('av_rech_amt_data_8', True, 1),
#  ('vol_2g_mb_6', False, 47),
#  ('vol_2g_mb_7', False, 29),
#  ('vol_2g_mb_8', True, 1),
#  ('vol_3g_mb_6', False, 39),
#  ('vol_3g_mb_7', True, 1),
#  ('vol_3g_mb_8', False, 13),
#  ('arpu_3g_6', False, 24),
#  ('arpu_3g_7', False, 21),
#  ('arpu_3g_8', True, 1),
#  ('arpu_2g_6', False, 25),
#  ('arpu_2g_7', True, 1),
#  ('arpu_2g_8', True, 1),
#  ('night_pck_user_6', False, 64),
#  ('night_pck_user_7', False, 65),
#  ('night_pck_user_8', False, 62),
#  ('monthly_2g_6', True, 1),
#  ('monthly_2g_7', False, 49),
#  ('monthly_2g_8', True, 1),
#  ('sachet_2g_6', False, 53),
#  ('sachet_2g_7', True, 1),
#  ('sachet_2g_8', False, 40),
#  ('monthly_3g_6', False, 46),
#  ('monthly_3g_7', False, 12),
#  ('monthly_3g_8', True, 1),
#  ('sachet_3g_6', False, 59),
#  ('sachet_3g_7', False, 2),
#  ('sachet_3g_8', False, 3),
#  ('fb_user_6', False, 31),
#  ('fb_user_7', False, 30),
#  ('fb_user_8', True, 1),
#  ('aon', True, 1),
#  ('aug_vbc_3g', True, 1),
#  ('jul_vbc_3g', True, 1),
#  ('jun_vbc_3g', False, 28)]

# %%
X_train_sc_df = pd.DataFrame(X_train_sc, columns = X_train.columns)
X_train_sc_df.head()
# Out:
#      arpu_6    arpu_7    arpu_8  onnet_mou_6  onnet_mou_7  onnet_mou_8  \
# 0 -0.956216  0.687844 -0.991586    -0.508198    -0.260900    -0.493094
# 1 -0.441984 -0.349220 -0.710710     0.664072     0.225604     0.303422
# 2  0.121899  0.728808  0.513644    -0.374334    -0.339777    -0.457452
# 3 -0.455933 -0.785935 -0.021523    -0.281184    -0.443905    -0.284479
# 4 -0.180267 -0.183825 -0.333031    -0.459697    -0.442753    -0.412345
#
#    offnet_mou_6  offnet_mou_7  offnet_mou_8  roam_ic_mou_6  ...  sachet_3g_6  \
# 0     -0.697066     -0.188431     -0.683250      -0.248433  ...    -0.194467
# 1      0.383886     -0.138089     -0.153620      -0.248433  ...    -0.194467
# 2     -0.232946      0.124255     -0.542051      -0.248433  ...    -0.194467
# 3     -0.262117     -0.533277      0.233512      -0.248433  ...    -0.194467
# 4     -0.153389     -0.104427     -0.289429       0.711869  ...    -0.194467
#
#    sachet_3g_7  sachet_3g_8  fb_user_6  fb_user_7  fb_user_8       aon  \
# 0    -0.193824    -0.196245  -0.547093  -0.550646  -0.551913 -0.463611
# 1    -0.193824    -0.196245  -0.547093  -0.550646  -0.551913  0.108838
# 2    -0.193824    -0.196245   1.827842   1.816047   1.811879  0.341395
# 3    -0.193824    -0.196245  -0.547093  -0.550646  -0.551913 -0.380480
# 4    -0.193824    -0.196245  -0.547093  -0.550646  -0.551913 -0.154236
#
#    aug_vbc_3g  jul_vbc_3g  jun_vbc_3g
# 0   -0.300594   -0.290242   -0.282305
# 1   -0.300594   -0.222196   -0.282305
# 2   -0.300594   -0.290242   -0.282305
# 3   -0.300594   -0.290242   -0.282305
# 4   -0.300594   -0.290242   -0.282305
#
# [5 rows x 124 columns]

# %%
col = X_train_sc_df.columns[rfe.support_]

# %%
grid = [
    {    "penalty":['l1','l2'],
        "class_weight":[{0:1,1:1}, {0:1,1:2}, {0:1,1:3}]
    }    
]

gscv = GridSearchCV(LogisticRegression(solver='lbfgs'), grid, cv = fold , scoring = 'accuracy', verbose = 1, n_jobs = -1)

# %%
gfit = gscv.fit(X_train_sc_df[col], y_train)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits

# %%
print("score : {}".format(gfit.best_score_))
logistic_params = gfit.best_params_
print(logistic_params)
# Out:
# score : 0.9165520863360775
# {'class_weight': {0: 1, 1: 2}, 'penalty': 'l2'}

# %%
lr_best_2 = gfit.best_estimator_

# %%
print(lr_best_2.coef_.shape)
lr_best_2.coef_
# Out:
# (1, 60)
# array([[ 0.51445291,  0.36540656,  0.3309232 ,  0.21326986, -0.75785851,
#          0.0729655 ,  0.24268408, -0.30451152,  0.0846942 , -0.25510211,
#         -0.6055366 , -0.12115244,  0.20963491,  1.25339552,  0.06495306,
#          0.07089242, -0.11354503, -0.22986037,  0.20004593, -0.81565636,
#         -0.10970379,  0.08570621, -0.44924387,  0.07928715, -0.18373046,
#         -0.06349976,  0.23051575,  0.16455788,  0.1489467 , -1.89924579,
#         -0.08824914, -0.07045073, -0.82278359,  0.26837953, -0.73926937,
#         -0.28022983, -0.15930971, -0.01921594, -0.23911712, -0.48439636,
#          0.09152213, -0.07206535, -0.16606691,  0.11021214,  0.14694015,
#         -0.13047116, -0.2400841 , -0.11347247, -0.10883688,  0.21904434,
#          0.18072155,  0.05638656, -0.06937539, -0.08055784,  0.11647654,
#         -0.17790849, -0.24631613, -0.38371918, -0.1768889 ,  0.09726889]])

# %%
LR_result = pd.DataFrame(lr_best_2.coef_.reshape(60,1), index = col, columns = ['Coef'])
LR_result.sort_values(by = 'Coef', key = abs, ascending = False).head(10)
# Out:
#                       Coef
# total_ic_mou_8   -1.899246
# std_og_mou_8      1.253396
# spl_ic_mou_8     -0.822784
# total_og_mou_8   -0.815656
# offnet_mou_8     -0.757859
# total_rech_num_8 -0.739269
# std_og_t2t_mou_8 -0.605537
# arpu_6            0.514453
# max_rech_amt_8   -0.484396
# loc_ic_t2f_mou_8 -0.449244

# %%
grid2 = [
    {   'n_estimators' : [250],
        'max_depth' : [ 7], 
        'max_features' : [20],
        'min_samples_split':[ 4],
    }    
]

gscv2 = RandomizedSearchCV(RandomForestClassifier(random_state = 100, class_weight = 'balanced'), grid2, cv = fold , scoring = 'accuracy', verbose = 1, n_jobs = -1)

# %%
gfit2 = gscv2.fit(X_train_sc_df[col], y_train)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits

# %%
print("score : {}".format(gfit2.best_score_))
gfit2.best_params_
# Out:
# score : 0.914337716754086
# {'n_estimators': 250,
#  'min_samples_split': 4,
#  'max_features': 20,
#  'max_depth': 7}

# %%
rf_best_2 = gfit2.best_estimator_

# %%
rf_df = pd.DataFrame({'feature' : X_train_sc_df[col].columns, 'importance' : rf_best_2.feature_importances_})
rf_df = rf_df.sort_values(by = 'importance', ascending = False).head(20)
fig = plt.figure(figsize = (12, 9))
sns.barplot(data = rf_df, y = 'feature', x = 'importance')
plt.show()

# %%
df_test_sc = sc.transform(df_test)

# %%
df_test_sc_pca = pca_ag.transform(df_test_sc)

# %%
y_pred_final = xgb_best.predict(df_test_sc_pca)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,

# %%
sample = pd.read_csv('../input/telecom-churn-case-study-hackathon-c34/sample.csv')
sample.head()
# Out:
#       id  churn_probability
# 0  69999                  0
# 1  70000                  0
# 2  70001                  0
# 3  70002                  0
# 4  70003                  0

# %%
sample['churn_probability'] = y_pred_final

# %%
sample['churn_probability'].value_counts()
# Out:
# 0    27994
# 1     2006
# Name: churn_probability, dtype: int64

# %%
submission = sample.to_csv('submissions.csv', index=False)

# %%
sample.head(10)
# Out:
#       id  churn_probability
# 0  69999                  0
# 1  70000                  0
# 2  70001                  0
# 3  70002                  0
# 4  70003                  0
# 5  70004                  1
# 6  70005                  0
# 7  70006                  0
# 8  70007                  0
# 9  70008                  0
